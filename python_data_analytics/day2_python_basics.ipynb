# %% [markdown]
# ## Day 2 - Python Basics for Data Analytics
# This notebook validates the Python and Jupyter environment
# and covers basic Python constructs used in data analytics.

# %%
x = 10
y = 3

x + y, x * y, x / y
# Out:
# (13, 30, 3.3333333333333335)
